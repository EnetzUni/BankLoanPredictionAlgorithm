# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Imports

# %%
import sys
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
# Allow the dataset to be loaded with both a Google Colab kernel and a local kernel

# Load the dataset with Google Colab kernel and Drive file
if 'google.colab' in sys.modules:
    # Time (aprox. 1m 30.0s)
    from pydrive2.auth import GoogleAuth
    from pydrive2.drive import GoogleDrive
    from google.colab import auth # type: ignore
    from oauth2client.client import GoogleCredentials

    # Authenticate the User in Google Drive
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

    # Google Drive ID for public sharing of the dataset
    file_id = "1HLAenC73QhLDCVAvgIw_2Y54Gwcq5S0D"
    file = drive.CreateFile({'id': file_id})
    file.GetContentFile('raw_data.csv')

    # Reading the csv and loading it into a pandas dataframe (Use pyarrow to prevent OOM error when loading)
    df = pd.read_csv("raw_data.csv", engine="pyarrow", dtype_backend="pyarrow")

# Load the dataset with local kernel and local file
else:
    # Time (13th Gen Intel Core i5-1335U: aprox. 3.0s; AMD Ryzen AI 9 HX 370 (24) @ 5.16 GHz: aprox. 1.0s)
    # Reading the csv and loading it into a pandas dataframe (Use pyarrow to prevent OOM error when loading)
    df = pd.read_csv("../data/raw/raw_data.csv", engine="pyarrow", dtype_backend="pyarrow")

# Stop Jupyter Notebook from limiting the output
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Display dataset head
df.head()
# Out:
#          id member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277      None     3600.0       3600.0           3600.0   36 months
# 1  68355089      None    24700.0      24700.0          24700.0   36 months
# 2  68341763      None    20000.0      20000.0          20000.0   60 months
# 3  66310712      None    35000.0      35000.0          35000.0   60 months
# 4  68476807      None    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85        829.9     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %% [markdown]
# ### Delete & Transform Columns & Rows

# %% [markdown]
# Display the missing values per column:

# %%
def print_column_info(df):
    # Get the total number of rows in the DataFrame
    total_rows = len(df)

    # Create the summary DataFrame
    data = pd.DataFrame({
        'Total (Null/Total)': df.isnull().sum().astype(str) + '/' + str(total_rows),
        'Percentage (%)': df.isnull().mean() * 100,
        'Data Type': df.dtypes
    })

    # Display the result
    display(data)

print_column_info(df)
# Out:
#                                            Total (Null/Total)  Percentage (%)  \
# id                                                  0/2260701        0.000000
# member_id                                     2260701/2260701      100.000000
# loan_amnt                                          33/2260701        0.001460
# funded_amnt                                        33/2260701        0.001460
# funded_amnt_inv                                    33/2260701        0.001460
# term                                               33/2260701        0.001460
# int_rate                                           33/2260701        0.001460
# installment                                        33/2260701        0.001460
# grade                                              33/2260701        0.001460
# sub_grade                                          33/2260701        0.001460
# emp_title                                      167002/2260701        7.387178
# ...

# %%
'''
Total (Null/Total)	Percentage (%)	Data Type
id	0/2260701	0.000000	string[pyarrow] # Change data type to int
member_id	2260701/2260701	100.000000	null[pyarrow] # Delete
loan_amnt	33/2260701	0.001460	double[pyarrow] # Nothing
funded_amnt	33/2260701	0.001460	double[pyarrow] # Delete, same shit as loan amount
funded_amnt_inv	33/2260701	0.001460	double[pyarrow] # Delete, same shit as loan amount
term	33/2260701	0.001460	string[pyarrow] # Convert to 0-1 and change data type to bool
int_rate	33/2260701	0.001460	double[pyarrow] # Nothing
installment	33/2260701	0.001460	double[pyarrow] # Nothing
grade	33/2260701	0.001460	string[pyarrow] # Delete, subgrade is same with more detail
sub_grade	33/2260701	0.001460	string[pyarrow] # Transform to numbers and change data type to int
emp_title	167002/2260701	7.387178	string[pyarrow] # Delete, because not usable
emp_length	146940/2260701	6.499754	string[pyarrow] # Transform to numbers and change data type to int
home_ownership	33/2260701	0.001460	string[pyarrow] # Transform to numbers and change data type to int
annual_inc	37/2260701	0.001637	double[pyarrow] # Nothing
verification_status	33/2260701	0.001460	string[pyarrow] # Delete
issue_d	33/2260701	0.001460	string[pyarrow] # Change data type to date32
loan_status	33/2260701	0.001460	string[pyarrow] # Delete all rows with current, transform to numbers and change data type to int
pymnt_plan	33/2260701	0.001460	string[pyarrow] # Delete (Data leakage)
url	33/2260701	0.001460	string[pyarrow] # Delete
desc	2134636/2260701	94.423632	string[pyarrow] # Delete
purpose	33/2260701	0.001460	string[pyarrow] # Transform to numbers and change data type to int
title	23359/2260701	1.033264	string[pyarrow] # Delete, purpose is same, with less detail, making it usable
zip_code	34/2260701	0.001504	string[pyarrow] # Delete, because not usable
addr_state	33/2260701	0.001460	string[pyarrow] # Transform to numbers and change data type to int
dti	1744/2260701	0.077144	double[pyarrow] # Nothing
delinq_2yrs	62/2260701	0.002743	double[pyarrow] # Nothing
earliest_cr_line	62/2260701	0.002743	string[pyarrow] # Change data type to date32
fico_range_low	33/2260701	0.001460	double[pyarrow] # Nothing
fico_range_high	33/2260701	0.001460	double[pyarrow] # Delete, almost same shit as fico_range_low
inq_last_6mths	63/2260701	0.002787	double[pyarrow] # Nothing
mths_since_last_delinq	1158535/2260701	51.246715	double[pyarrow] # Nothing
mths_since_last_record	1901545/2260701	84.113069	double[pyarrow] # Nothing
open_acc	62/2260701	0.002743	double[pyarrow] # Nothing
pub_rec	62/2260701	0.002743	double[pyarrow] # Nothing
revol_bal	33/2260701	0.001460	double[pyarrow] # Nothing
revol_util	1835/2260701	0.081170	double[pyarrow] # Nothing
total_acc	62/2260701	0.002743	double[pyarrow] # Nothing
initial_list_status	33/2260701	0.001460	string[pyarrow] # Convert to 0-1 and change data type to bool
out_prncp	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
out_prncp_inv	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
total_pymnt	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
total_pymnt_inv	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
total_rec_prncp	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
total_rec_int	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
total_rec_late_fee	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
recoveries	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
collection_recovery_fee	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
last_pymnt_d	2460/2260701	0.108816	string[pyarrow] # Delete (Data leakage)
last_pymnt_amnt	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
next_pymnt_d	1345343/2260701	59.509993	string[pyarrow] # Delete (Data leakage)
last_credit_pull_d	105/2260701	0.004645	string[pyarrow] # Delete (Data leakage)
last_fico_range_high	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
last_fico_range_low	33/2260701	0.001460	double[pyarrow] # Delete (Data leakage)
collections_12_mths_ex_med	178/2260701	0.007874	double[pyarrow] # Delete (Data leakage)
mths_since_last_major_derog	1679926/2260701	74.309960	double[pyarrow] # Nothing
policy_code	33/2260701	0.001460	double[pyarrow] # Delete
application_type	33/2260701	0.001460	string[pyarrow] # Convert to 0-1 and change data type to bool
annual_inc_joint	2139991/2260701	94.660506	double[pyarrow] # Delete
num_tl_90g_dpd_24m	70309/2260701	3.110053	double[pyarrow] # Delete (Data leakage)
num_tl_op_past_12m	70309/2260701	3.110053	double[pyarrow] # Delete (Data leakage)
pct_tl_nvr_dlq	70464/2260701	3.116909	double[pyarrow] # Nothing
percent_bc_gt_75	75412/2260701	3.335779	double[pyarrow] # Nothing
pub_rec_bankruptcies	1398/2260701	0.061839	double[pyarrow] # Nothing
tax_liens	138/2260701	0.006104	double[pyarrow] # Nothing
tot_hi_cred_lim	70309/2260701	3.110053	double[pyarrow] # Nothing
total_bal_ex_mort	50063/2260701	2.214490	double[pyarrow] # Nothing
total_bc_limit	50063/2260701	2.214490	double[pyarrow] # Nothing
total_il_high_credit_limit	70309/2260701	3.110053	double[pyarrow] # Nothing
revol_bal_joint	2152681/2260701	95.221836	double[pyarrow] # Delete
sec_app_fico_range_low	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_fico_range_high	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_earliest_cr_line	2152680/2260701	95.221792	string[pyarrow] # Delete
sec_app_inq_last_6mths	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_mort_acc	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_open_acc	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_revol_util	2154517/2260701	95.303050	double[pyarrow] # Delete
sec_app_open_act_il	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_num_rev_accts	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_chargeoff_within_12_mths	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_collections_12_mths_ex_med	2152680/2260701	95.221792	double[pyarrow] # Delete
sec_app_mths_since_last_major_derog	2224759/2260701	98.410139	double[pyarrow] # Delete
hardship_flag	33/2260701	0.001460	string[pyarrow] # Delete (Data leakage)
hardship_type	2249784/2260701	99.517097	string[pyarrow] # Delete
hardship_reason	2249784/2260701	99.517097	string[pyarrow] # Delete
hardship_status	2249784/2260701	99.517097	string[pyarrow] # Delete
deferral_term	2249784/2260701	99.517097	double[pyarrow] # Delete
hardship_amount	2249784/2260701	99.517097	double[pyarrow] # Delete
hardship_start_date	2249784/2260701	99.517097	string[pyarrow] # Delete
hardship_end_date	2249784/2260701	99.517097	string[pyarrow] # Delete
payment_plan_start_date	2249784/2260701	99.517097	string[pyarrow] # Delete
hardship_length	2249784/2260701	99.517097	double[pyarrow] # Delete
hardship_dpd	2249784/2260701	99.517097	double[pyarrow] # Delete
hardship_loan_status	2249784/2260701	99.517097	string[pyarrow]
orig_projected_additional_accrued_interest	2252050/2260701	99.617331	double[pyarrow] # Delete
hardship_payoff_balance_amount	2249784/2260701	99.517097	double[pyarrow] # Delete
hardship_last_payment_amount	2249784/2260701	99.517097	double[pyarrow] # Delete
disbursement_method	33/2260701	0.001460	string[pyarrow] # Delete (Data leakage)
debt_settlement_flag	33/2260701	0.001460	string[pyarrow] # Delete (Data leakage)
debt_settlement_flag_date	2226455/2260701	98.485160	string[pyarrow] # Delete
settlement_status	2226455/2260701	98.485160	string[pyarrow] # Delete
settlement_date	2226455/2260701	98.485160	string[pyarrow] # Delete
settlement_amount	2226455/2260701	98.485160	double[pyarrow] # Delete
settlement_percentage	2226455/2260701	98.485160	double[pyarrow] # Delete
settlement_term	2226455/2260701	98.485160	double[pyarrow] # Delete
'''
# Out:
# ''
